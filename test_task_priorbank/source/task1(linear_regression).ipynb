# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_excel("dataset.xlsx", sheet_name='regression')

# %%
plt.style.use('ggplot')
plt.figure(figsize= (10, 6))
plt.grid(True)
plt.plot(x, model.predict(x), c= 'blue')
plt.scatter(data.X, data.Y )
plt.ylim(0, 8200)
plt.xlim(0, 550)
# Out:
# (0.0, 550.0)

# %%
model = LinearRegression()

# %%
x = pd.DataFrame(data.X)
y = pd.DataFrame(data.Y)

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
model.coef_ #coeff B
# Out:
# array([[16.00001026]])

# %%
model.intercept_ #coeff A
# Out:
# array([5.48501032])

# %%
model.score(x, y) #coefficient of determination
# Out:
# 0.9999999842497201
